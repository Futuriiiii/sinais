# %% [markdown]
# # $$ \textbf{Lista $2b$ - Sinais e Sistemas Dinâmicos 2023.1}$$
#
# <div>
# <img src="attachment:logoCI.jpeg" width="80">
# </div>

# %% [markdown]
# Esta lista aborda o tema *Análise de sinais no tempo contínuo - a transformada de Fourier*.
#
# Vamos usar a notação:
#
# $$
# X(\omega)=\mathcal{F}[x(t)] \quad \text { e } \quad x(t)=\mathcal{F}^{-1}[X(\omega)]
# $$
# ou
# $$
# x(t) \Longleftrightarrow X(\omega)
# $$
#
#
# E a tabela:
#
# | $N^{0}$&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;|$x(t)$ &nbsp;|$X(\omega)$&nbsp;|     |
# |:-------:|:-----------------------------------------------------------------:|:----------------------------------------------------------------------------------------------------------------------------------------:|:--------------------------:|
# |    1    |                          $e^{-a t} u(t)$                          |                                                          $\frac{1}{a+j \omega}$                                                          |            $a>0$           |
# |    2    |                          $e^{a t} u(-t)$                          |                                                          $\frac{1}{a-j \omega}$                                                          |            $a>0$           |
# |    3    |                           $e^{-a\|t\|}$                           |                                                        $\frac{2 a}{a^2+\omega^2}$                                                        |            $a>0$           |
# |    4    |                         $t e^{-a t} u(t)$                         |                                                        $\frac{1}{(a+j \omega)^2}$                                                        |            $a>0$           |
# |    5    |                        $t^n e^{-a t} u(t)$                        |                                                     $\frac{n !}{(a+j \omega)^{n+1}}$                                                     |            $a>0$           |
# |    6    |                            $\delta(t)$                            |                                                                    $1$                                                                   |                            |
# |    7    |                                $1$                                |                                                          $2 \pi \delta(\omega)$                                                          |                            |
# |    8    |                         $e^{j \omega_0 t}$                        |                                                $2 \pi \delta\left(\omega-\omega_0\right)$                                                |                            |
# |    9    |                         $\cos \omega_0 t$                         |                          $\pi\left[\delta\left(\omega-\omega_0\right)+\delta\left(\omega+\omega_0\right)\right]$                         |                            |
# |    10   |                  $\operatorname{sen} \omega_0 t$                  |                         $j \pi\left[\delta\left(\omega+\omega_0\right)-\delta\left(\omega-\omega_0\right)\right]$                        |                            |
# |    11   |                               $u(t)$                              |                                                  $\pi \delta(\omega)+\frac{1}{j \omega}$                                                 |                            |
# |    12   |                       $\operatorname{sgn} t$                      |                                                           $\frac{2}{j \omega}$                                                           |                            |
# |    13   |                       $\cos \omega_0 t u(t)$                      |  $\frac{\pi}{2}\left[\delta\left(\omega-\omega_0\right)+\delta\left(\omega+\omega_0\right)\right]+\frac{j \omega}{\omega_0^2-\omega^2}$  |                            |
# |    14   |                $\operatorname{sen} \omega_0 t u(t)$               | $\frac{\pi}{2 j}\left[\delta\left(\omega-\omega_0\right)-\delta\left(\omega+\omega_0\right)\right]+\frac{\omega_0}{\omega_0^2-\omega^2}$ |                            |
# |    15   |           $e^{-a t} \operatorname{sen} \omega_0 t u(t)$           |                                               $\frac{\omega_0}{(a+j \omega)^2+\omega_0^2}$                                               |            $a>0$           |
# |    16   |                  $e^{-a t} \cos \omega_0 t u(t)$                  |                                              $\frac{a+j \omega}{(a+j \omega)^2+\omega_0^2}$                                              |            $a>0$           |
# |    17   |          $\operatorname{ret}\left(\frac{t}{\tau}\right)$          |                                       $\tau \operatorname{sinc}\left(\frac{\omega \tau}{2}\right)$                                       |                            |
# |    18   |              $\frac{W}{\pi} \operatorname{sinc}(W t)$             |                                            $\operatorname{ret}\left(\frac{\omega}{2 W}\right)$                                           |                            |
# |    19   |                $\Delta\left(\frac{t}{\tau}\right)$                |                                 $\frac{\tau}{2} \operatorname{sinc}^2\left(\frac{\omega \tau}{4}\right)$                                 |                            |
# |    20   | $\frac{W}{2 \pi} \operatorname{sinc}^2\left(\frac{W t}{2}\right)$ |                                                  $\Delta\left(\frac{\omega}{2 W}\right)$                                                 |                            |
# |    21   |             $\sum_{n=-\infty}^{\infty} \delta(t-n T)$             |                                 $\omega_0 \sum_{n=-\infty}^{\infty} \delta\left(\omega-n \omega_0\right)$                                | $\omega_0=\frac{2 \pi}{T}$ |
# |    22   |                      $e^{-t^2 / 2 \sigma^2}$                      |                                             $\sigma \sqrt{2 \pi} e^{-\sigma^2 \omega^2 / 2}$                                             |                            |

# %% [markdown]
# ### Questão 1.
#
# a) Mostre que se $x(t)$ é um sinal periódico, dado por
# $$
# x(t)=\sum_{n=-\infty}^{\infty} D_n e^{j n \omega_0 t}, \quad \omega_0=\frac{2 \pi}{T_0}
# $$
#
# Podemos escrever:
# $$
# X(\omega)=2 \pi \sum_{n=-\infty}^{\infty} D_n \delta\left(\omega-n \omega_0\right).
# $$
#
# b) Use o resultado do item a) para mostrar que a transformada de Fourier do trem de impulso unitário é
# $$
# X(\omega) =\frac{2 \pi}{T_0} \sum_{n=-\infty}^{\infty} \delta\left(\omega-n \omega_0\right) =\omega_0 \delta_{\omega_0}(\omega)
# $$

# %% [markdown]
# ### Questão 2.
#
# Obtenha a transformada de Fourier da função sinal $\operatorname{sgn}(t)$, dada por
#
# $$
# \operatorname{sgn}(t) =
# \begin{cases}
# 1, \text{ se } t > 0 \\
# 0, \text{ se } t = 0\\
# -1, \text{ se } t < 0.
# \end{cases}
# $$

# %% [markdown]
# ### Questão 3.
# Mostre que
# $$
#  \cos \left(\omega_0 t+\theta\right) \Leftrightarrow \pi\left[\delta\left(\omega+\omega_0\right) e^{-j \theta}+\delta\left(\omega-\omega_0\right) e^{j \theta}\right] \text {. }
# $$

# %% [markdown]
# ### Dualidade
# A propriedade da dualidade afirma que se
# $$
# x(t) \Longleftrightarrow X(\omega)
# $$
# então
# $$
# X(t) \Longleftrightarrow 2 \pi x(-\omega)
# $$

# %% [markdown]
# ### Questão 4.
#
# Aplique a propriedade da dualidade aos pares 1,3 e 9 da tabela para mostrar que:
#
# (a) $1 /(j t+a) \Longleftrightarrow 2 \pi e^{a \omega} u(-\omega)$
#
# (b) $2 a /\left(t^2+a^2\right) \Longleftrightarrow 2 \pi e^{-a|\omega|}$
#
# (c) $\delta\left(t+t_0\right)+\delta\left(t-t_0\right) \Longleftrightarrow 2 \cos t_0 \omega$

# %% [markdown]
# ### Propriedade de Escalamento
# Se
# $$
# x(t) \Longleftrightarrow X(\omega)
# $$
# então, para qualquer constante real $a$,
# $$
# x(a t) \Longleftrightarrow \frac{1}{|a|} X\left(\frac{\omega}{a}\right)
# $$

# %% [markdown]
# ### Questão 5.
#
# Obtenha as transformadas de Fourier de $e^{a t} u(-t)$ e $e^{-a|t|}$.

# %% [markdown]
# ### Propriedade de Deslocamento no Tempo
# Se
#
# $$
# x(t) \Longleftrightarrow X(\omega)
# $$
# então
# $$
# x\left(t-t_0\right) \Longleftrightarrow X(\omega) e^{-j \omega t_0}
# $$

# %% [markdown]
# ### Questão 6.
#
# Obtenha a transformada de Fourier de $e^{-a\left|t-t_o\right|}$.

# %% [markdown]
# ### Questão 7.
#
# Obtenha a transformada de Fourier do pulso de porta $x(t)$ ilustrado na figura abaixo.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Questão 8.
#
# Usando o par 18 da tabela e a propriedade de deslocamento no tempo, mostre que a transformada de Fourier de
# $\operatorname{sinc} \left[\omega_0(t-T)\right]$ é
# $$\left(\pi / \omega_0\right) \operatorname{ret} \left(\omega / 2 \omega_0\right) e^{-j \omega T}.$$
#
# Trace o espectro de amplitude e fase da transformada de Fourier.

# %% [markdown]
# ### Questão 9.
#
# Determine e trace a transformada de Fourier do sinal modulado $x(t) \cos 10 t$ no qual $x(t)$ é um pulso de porta ret $(t / 4)$ como ilustrado na figura abaixo.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Questão 10.
#
# Mostre que
# $$
# x(t) \cos \left(\omega_0 t+\theta\right) \Longleftrightarrow \frac{1}{2}\left[X\left(\omega-\omega_0\right) e^{j \theta}+X\left(\omega+\omega_0\right) e^{-j \theta}\right]
# $$

# %% [markdown]
# ### Questão 11.
#
# Trace o sinal $e^{-|t|} \cos 10 t$. Determine a transformada de Fourier deste sinal e trace seu espectro.

# %% [markdown]
# ### Convolução
#
# A propriedade de convolução no tempo e sua dual, a propriedade de convolução na frequiência, afirma que se
# $$
# x_1(t) \Longleftrightarrow X_1(\omega) \quad \text { e } \quad x_2(t) \Longleftrightarrow X_2(\omega)
# $$
# então
# $$
# x_1(t) * x_2(t) \Longleftrightarrow X_1(\omega) X_2(\omega) \quad \text { (convolução no tempo) }
# $$
# e
# $$
# x_1(t) x_2(t) \Longleftrightarrow \frac{1}{2 \pi} X_1(\omega) * X_2(\omega) \quad \text { (convolução na frequência) }
# $$

# %% [markdown]
# ### Questão 12.
#
# Utilize a propriedade de convolução no tempo para mostrar que se
# $$
# x(t) \Longleftrightarrow X(\omega)
# $$
# então
# $$
# \int_{-\infty}^t x(\tau) d \tau \Longleftrightarrow \frac{X(\omega)}{j \omega}+\pi X(0) \delta(\omega)
# $$

# %% [markdown]
# ### Questão 13.
#
# Utilize a propriedade da convolução no tempo para mostrar que
#
# $$x(t) * \delta(t)=x(t)$$

# %% [markdown]
# ### Questão 14.
#
# Utilize a propriedade de convolução no tempo para mostrar que
# $$
# e^{-a t} u(t) * e^{-b t} u(t)=\frac{1}{b-a}\left[e^{-a t}-e^{-b t}\right] u(t)
# $$

# %% [markdown]
# ### Diferenciação e Integração no Tempo
#
# Se
#
# $$
# x(t) \Longleftrightarrow X(\omega)
# $$
# então
# $$
# \frac{d x}{d t} \Longleftrightarrow j \omega X(\omega) \quad \text { (diferenciação no tempo) }
# $$
# e
# $$
# \int_{-\infty}^t x(\tau) d \tau \Longleftrightarrow \frac{X(\omega)}{j \omega}+\pi X(0) \delta(\omega) \quad \text { (integração no tempo) }
# $$

# %% [markdown]
# ### Questão 14.
#
# Utilize a propriedade de diferenciação no tempo para obter a transformada de Fourier do pulso triangular $\Delta(t / \tau)$ apresentado na figura abaixo.
#
# ![image.png](attachment:image.png)
