# %% [markdown]
# ## $$ \textbf{Exercícios Selecionados de Sinais e Sistemas Dinâmicos 2023.1 - Unidade 1}$$
#
# <div>
# <img src="attachment:logoCI.jpeg" width="100">
# </div>
#
#
# Nome:__________________________________________________________________
#
# Matrícula:__________________________________      (21 de agosto de 2023).

# %% [markdown]
# ### Notações
#
#  - $v(t)$ e $v(k) $ são os sinais degrau unitário para os casos contínuo e discreto no tempo, respectivamente;
#
#  - $\delta(t)$ e $\delta(k)$ são os sinais impulso unitário para os casos contínuo e discreto no tempo, respectivamente.
#
#
# ### Questão 1.
#
# Considere o sistema $S$ tal que $S[g(t)] = \frac{1}{2}\int^{+ \infty}_{-\infty} g(\tau) \left[\delta(t - \tau) + \delta(t +  \tau) \right]d\tau$:
#
# i. descreva o comportamento do sistema S. Qual a saída esperada para uma função par? e para uma função ímpar?
#
# ii. O sistema $S$ é linear? Invariante no tempo? Causal? Justifique.
#
# iii. O que se pode dizer acerca da estabilidade de $S$? Justifique.
#
# iv. Considere os itens i. a iii. para o sistema $\tilde{S}$ tal que  $\tilde{S}[g(t)] = \frac{1}{2}\int^{+ \infty}_{-\infty} g(\tau) \left[\delta(t - \tau) + \delta(-t +  \tau) \right]d\tau$:

# %% [markdown]
# ### Questão 2.
#
# Considere o sinal $f(t)$ representado na figura abaixo:
#
# ![fig1.png](attachment:fig1.png)
#
#  a. Esboce o gráfico da resposta do sistema $S[f(t)] = f(-t/2 + 1)$;
#
#  b. $S$ é linear? Invariante no tempo? Causal? Estável? Justifique.

# %% [markdown]
# ### Questão 3.
#
# Determine a potência média $P$ e a energia $E$ dos sinais abaixo:
#
# i. $f(k) = \frac{1}{2}^{k}v(k), \quad \forall k \in \mathbb{Z},$
#
# ii. $f(t) = e^{2t}v(-t), \quad \forall t \in \mathbb{R}$.

# %% [markdown]
# ### Questão 4.
#
# Um sistema $S$, linear e invariante no tempo, apresenta como resposta ao impulso unitário a função degrau unitário ($h(t) = S[\delta(t)] = v(t)$).
#
# i. determine a saída correspondente à entrada $g(t) = e^{-at}v(t), \quad a>0.$
#
# ii. o que se pode afirmar acerca da estabilidade do sistema $S$?
